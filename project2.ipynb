# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.boxofficemojo.com/studio/?view=parent&view2=yearly&yr=2016&p=.htm"
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
print(response.text)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <HEAD>
# <TITLE>2016 Market Share and Box Office Results by Movie Studio</TITLE>
#
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8"></head>
# <body >
# <iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
# ...

# %%
page = response.text
soup = BeautifulSoup(page)
soup
# Out:
# C:\Python34\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <title>2016 Market Share and Box Office Results by Movie Studio</title>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css">
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/></link></head>
# <body>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <title>
#    2016 Market Share and Box Office Results by Movie Studio
#   </title>
#   <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css">
#    <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
#   </link>
#  </head>
#  <body>
#   <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1">
#   </iframe>
#   <script>
#    setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
# ...

# %%
soup.find_all('table')[3]
# Out:
# <table border="0" cellpadding="5" cellspacing="1"><tr bgcolor="#dcdcdc"><td align="center"><font size="2">Rank</font></td><td align="center"><font size="2">Distributor</font></td><td align="center"><font size="2"><b>Market<br>Share</br></b></font></td><td align="center"><font size="2">Total<br>Gross*</br></font></td><td align="center"><font size="2">Movies<br>Tracked</br></font></td><td align="center"><font size="2">2016<br>Movies**</br></font></td></tr><tr bgcolor="#ffffff"><td align="center"><font size="2">1</font></td>
# <td><font size="2"><a href="/studio/chart/?yr=2016&amp;view=parent&amp;studio=buenavista.htm"><b>Disney</b></a></font></td>
# <td align="right"><font size="2"><b>32.2%</b></font></td>
# <td align="right"><font size="2">$1,972.0</font></td>
# <td align="center"><font size="2">10</font></td>
# <td align="center"><font size="2">7</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td align="center"><font size="2">2</font></td>
# ...

# %%
for table in soup.find_all('table'):
    print(len(table))
# Out:
# 3
# 1
# 1
# 233
# 1

# %%
tableOfInterest = soup.find_all('table')[3]
table_content = tableOfInterest.find_all('tr')
table_content
# Out:
# [<tr bgcolor="#dcdcdc"><td align="center"><font size="2">Rank</font></td><td align="center"><font size="2">Distributor</font></td><td align="center"><font size="2"><b>Market<br>Share</br></b></font></td><td align="center"><font size="2">Total<br>Gross*</br></font></td><td align="center"><font size="2">Movies<br>Tracked</br></font></td><td align="center"><font size="2">2016<br>Movies**</br></font></td></tr>,
#  <tr bgcolor="#ffffff"><td align="center"><font size="2">1</font></td>
#  <td><font size="2"><a href="/studio/chart/?yr=2016&amp;view=parent&amp;studio=buenavista.htm"><b>Disney</b></a></font></td>
#  <td align="right"><font size="2"><b>32.2%</b></font></td>
#  <td align="right"><font size="2">$1,972.0</font></td>
#  <td align="center"><font size="2">10</font></td>
#  <td align="center"><font size="2">7</font></td>
#  </tr>,
#  <tr bgcolor="#f4f4ff"><td align="center"><font size="2">2</font></td>
# ...

# %%
tableOfInterest = soup.find_all('table')[3]
table_content = tableOfInterest.find_all('td')
for i in table_content:
    print(i.text)
# Out:
# Rank
# Distributor
# MarketShare
# TotalGross*
# MoviesTracked
# 2016Movies**
# 1
# Disney
# 32.2%
# $1,972.0
# 10
# 7
# 2
# News Corporation (Fox)
# 17.3%
# $1,058.8
# 18
# 10
# 3
# Time Warner (WB/New Line)
# 14.1%
# $863.3
# 22
# 10
# 4
# NBC/Universal
# 12.0%
# $735.8
# 24
# 19
# 5
# Viacom (Paramount)
# 6.5%
# $396.3
# 9
# 6
# 6
# Sony
# 6.4%
# $394.4
# 27
# 17
# 7
# Lionsgate
# 4.5%
# $272.6
# 13
# 10
# 8
# Open Road Films
# 1.2%
# $76.0
# 4
# 3
# 9
# STX Entertainment
# 1.1%
# $64.5
# 4
# 3
# 10
# Weinstein Company
# 0.9%
# $54.8
# 8
# 4
# 11
# A24
# 0.8%
# $50.2
# 11
# 9
# 12
# Roadside Attractions
# 0.6%
# $35.4
# 7
# 6
# 13
# Bleecker Street
# 0.3%
# $20.9
# 4
# 3
# 14
# Pure Flix
# 0.3%
# $20.8
# 2
# 1
# 15
# Gramercy
# 0.2%
# $12.7
# 1
# 1
# 16
# IFC
# 0.2%
# $11.4
# 14
# 13
# 17
# High Top Releasing
# 0.2%
# $10.8
# 1
# 1
# 18
# Freestyle Releasing
# 0.2%
# $9.4
# 5
# 4
# 19
# Yash Raj
# 0.1%
# $5.1
# 2
# 2
# 20
# FIP
# 0.1%
# $4.2
# 2
# 2
# 21
# Drafthouse
# 0.1%
# ...

# %% [markdown]
# # I am going to start pulling by Genre

# %%
urlGenre = 'http://www.boxofficemojo.com/genres/'
responseGenre = requests.get(urlGenre)

# %%
pageGenre = responseGenre.text
soupGenre = BeautifulSoup(pageGenre)

tableGenre = soupGenre.find_all('table')

#check the len of each element of above table:
for element in tableGenre:
    print(len(element))
# Out:
# 2
# 3
# 1
# 426
# C:\Python34\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %% [markdown]
# Based on the data above it seem that the 3rd one is most relevant

# %%
header_list = []

for i in tableGenreOfInterest.find('tr').find_all('td'):
    header_list.append(i.text)
    
header_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-65838524e3ee> in <module>()
#       1 header_list = []
#       2
# ----> 3 for i in tableGenreOfInterest.find('tr').find_all('td'):
#       4     header_list.append(i.text)
#       5
#
# NameError: name 'tableGenreOfInterest' is not defined

# %%
# this function is actually going to go through each row
tableGenreOfInterest = tableGenre[3]
#for element in tableGenreOfInterest.find_all('tr'):
for index,element in enumerate(tableGenreOfInterest.findAll('tr')):
    print(index, element.text, element.find_all('a')[1].get('href'))
    #print(element.find_all('a')[1].get('href'))
    print('-----------')
# Out:
# 0 Genre (click to view chart)# Movies#1 PictureGross* /genres/?sort=nummovies&order=DESC&p=.htm
# -----------
# 1 3D
# 269
# Star Wars: The Force Awakens
# $936.7
#  /movies/?id=starwars7.htm
# -----------
# 2 Action - Buddy Comedy
# 82
# Men in Black
# $250.7
#  /movies/?id=meninblack.htm
# -----------
# 3 Action - Martial Arts
# 163
# Rush Hour 2
# $226.2
#  /movies/?id=rushhour2.htm
# -----------
# 4 Action - Wire-Fu
# 27
# The Matrix Reloaded
# $281.6
#  /movies/?id=matrixreloaded.htm
# -----------
# 5 Action Heroine
# 68
# Catching Fire
# $424.7
#  /movies/?id=catchingfire.htm
# -----------
# 6 Action Remake
# 25
# The Karate Kid
# $176.6
#  /movies/?id=karatekid2010.htm
# -----------
# 7 Adventure - Desert
# 24
# Mummy Returns
# $202.0
#  /movies/?id=mummyreturns.htm
# -----------
# 8 Adventure - Period
# 79
# Dead Man's Chest
# $423.3
#  /movies/?id=piratesofthecaribbean2.htm
# -----------
# 9 Adventure Remake
# 27
# The Jungle Book
# $360.3
#  /movies/?id=junglebook2015.htm
# ...

# %% [markdown]
# # Change of idea
# 1. concentrate on action movies
# 2. see where international chunk is more
# 3. see the timeline in transition and see if china is responsible
#
# 4. see how tastes depend on region

# %%
urlWwGross2016 = 'http://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=2016&p=.htm'
responsewwGross2016 = requests.get(urlWwGross2016)

# %%
pageWwGross2016 = responsewwGross2016.text
soupWwGross2016 = BeautifulSoup(pageWwGross2016)

tableWwGross2016 = soupWwGross2016.find_all('table')

#check the len of each element of above table:
for element in tableWwGross2016:
    print(len(element))
# Out:
# 2
# 3
# 1
# 451
# 2
# 3
# C:\Python34\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
#for element in tableWwGross2016[3].find_all('tr'):
#    print(len(element))
    
dataJumble = tableWwGross2016[3].find_all('tr')
    
dataJumble[0].text

header = ['Rank', 'Title', 'Worldwide_percentage','Overseas_percentage']

dataJumble
# Out:
# [<tr bgcolor="#dcdcdc"><td align="center"><font size="2"><a href="/yearly/chart/?view2=worldwide&amp;yr=2016&amp;sort=rank&amp;order=ASC&amp;p=.htm">Rank</a></font></td><td align="center"><font size="2"><a href="/yearly/chart/?view2=worldwide&amp;yr=2016&amp;sort=title&amp;order=ASC&amp;p=.htm">Title (click to view)</a></font></td><td align="center"><font size="2"><a href="/yearly/chart/?view2=worldwide&amp;yr=2016&amp;sort=studio&amp;order=ASC&amp;p=.htm">Studio*</a><br><script language="javascript">
#  function MojoDrop1() {
#  var number = document.MojoDropDown1.mojolinks1.selectedIndex;location.href = document.MojoDropDown1.mojolinks1.options[number].value;}</script>
#  <table border="0" cellpadding="0" cellspacing="0">
#  <form name="MojoDropDown1"><tr><td>
#  <select name="mojolinks1" onchange="MojoDrop1(this.form)" style="font-family: Verdana; font-size: 8pt">
# ...

# %%
len(dataJumble)
# Out:
# 227

# %%
listOfTable = []

for rowNum in range(2, len(dataJumble)):
    listOfData = dataJumble[rowNum].find_all('td')
    rowData = []
    for i in listOfData[1:]:
        rowData.append(i.text)
    rowData.append(listOfData[1].find('a').get('href'))
    listOfTable.append(rowData)

import pandas as pd

df = pd.DataFrame(listOfTable)
df.columns = ['Movie','Distributor','WW_gross','Domestic_gross','Domestic_percentage','Intr_gross','Intr_percentage','Movie_link']
df
# Out:
#                                                 Movie  Distributor  WW_gross  \
# 0                          Captain America: Civil War           BV  $1,151.0
# 1                                            Zootopia           BV  $1,021.7
# 2                              The Jungle Book (2016)           BV    $936.8
# 3                  Batman v Superman: Dawn of Justice           WB    $872.7
# 4                                            Deadpool          Fox    $782.0
# 5                                        Finding Dory           BV    $721.9
# 6                            The Mermaid (Mei ren yu)         Sony    $553.8
# 7                                   X-Men: Apocalypse          Fox    $533.9
# 8                                     Kung Fu Panda 3          Fox    $519.0
# 9                                            Warcraft         Uni.    $432.2
# 10                                       Monster Hunt           FR    $385.3
# ...

# %% [markdown]
# ### Trying out new year

# %%
urlWwGross2015 = 'http://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=2015&p=.htm'
responseWwGross2015 = requests.get(urlWwGross2015)
pageWwGross2015 = responseWwGross2015.text
soupWwGross2015 = BeautifulSoup(pageWwGross2015)
tableWwGross2015 = soupWwGross2015.find_all('table')

dataJumble2 = tableWwGross2015[3].find_all('tr')
listOfData2 = dataJumble2[2].find_all('td')

listOfTable2 = []

pageWwGross2015
'''
for rowNum in range(2, len(dataJumble2)):
    listOfTable2 = dataJumble2[rowNum].find_all('td')
    rowData = []
    ''''''
    for i in listOfData2[1:]:
        rowData.append(i.text)
    rowData.append(listOfData[1].find('a').get('href'))
    listOfData2.append(rowData)


df2 = pd.DataFrame(listOfData2)
df2.columns = ['Movie','Distributor','WW_gross','Domestic_gross','Domestic_percentage','Intr_gross','Intr_percentage','Movie_link']
df2
'''
# Out:
# C:\Python34\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# "\nfor rowNum in range(2, len(dataJumble2)):\n    listOfTable2 = dataJumble2[rowNum].find_all('td')\n    rowData = []\n    \n    for i in listOfData2[1:]:\n        rowData.append(i.text)\n    rowData.append(listOfData[1].find('a').get('href'))\n    listOfData2.append(rowData)\n\n\ndf2 = pd.DataFrame(listOfData2)\ndf2.columns = ['Movie','Distributor','WW_gross','Domestic_gross','Domestic_percentage','Intr_gross','Intr_percentage','Movie_link']\ndf2\n"
