# %%
import pandas as pd
import requests
import time
import random

import numpy as np
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup

def findRelevantData(tableElement):
    listOfTableData = tableElement.find_all('td')
    distributorText = listOfTableData[2].text.split(':')[1].strip()
    
    # convert to actual number
    prodBudget = listOfTableData[-1].text.split(':')[1].strip()
    mpaa_rating = listOfTableData[-2].text.split(':')[1].strip()
    
    # convert this to datetime
    releaseDate = listOfTableData[3].text.split(':')[1].strip()
    
    runTime = listOfTableData[-3].text.split(':')[1].strip()
    genre = listOfTableData[4].text.split(':')[1].strip()
    
    return distributorText, prodBudget, mpaa_rating, releaseDate, runTime, genre

def pullData(subUrl):

    url = 'http://www.boxofficemojo.com/movies/?page=intl&'+subUrl

    resp = requests.get(url)
    page = resp.text
    soup = BeautifulSoup(page)

    box = soup.find_all('table')

    topBox = box[4]
    countryData = box[7]

    countryDataList = []
    for row in countryData.find_all('tr'):

        rowData = []
        rowData = [x.text for x in row.find_all('td')]
        countryDataList.append(rowData)

    header2 = ['Country','Dist','ReleaseDate','OpeningWknd','PercentTotal','TotalGross','TotalGrossDate']
    data = countryDataList[3:]

    df = pd.DataFrame(data)
    df.columns = header2

    # Adding information from topbox of movie
    topBoxHeader = ['UsDist','UsRelease','Genre','Runtime','MpaaRating','ProdBudget']
    for element in zip(topBoxHeader, findRelevantData(topBox)):
        df[element[0]] = element[1]
    fileToSaveAs = subUrl.split('=')[1].split('.')[0]+'.csv'
    df.to_csv(fileToSaveAs, encoding='utf-8')

ww2016 = pd.read_csv("worldwide_releases_2016_v2.csv")

linkList = []
for index, element in ww2016.iterrows():
    title = element.Movie_link.split('?')[1].split('.')[0]
    linkList.append(title)
    
for i in linkList:
    print(i)
'''
ww2016 = pd.read_csv("worldwide_releases_2016_v2.csv")

for index, element in ww2016.iterrows():
    title = element.Movie_link.split('?')[1].split('.')[0]
    print(title)
    time.sleep(random.randint(3,7))
    pullData(title)
    time.sleep(random.randint(3,7))
'''
# Out:
# id=marvel2016
# id=disney2016
# id=junglebook2015
# id=superman2015
# id=deadpool2016
# id=pixar2015
# id=mermaid2016
# id=x-men2016
# id=kungfupanda3
# id=warcraft
# id=monsterhunt
# id=angrybirds
# id=id42
# id=conjuring2
# id=alice2
# id=nowyouseeme2
# id=illumination2015
# id=tmnt2016
# id=londonhasfallen
# id=tarzan2016
# id=monkeyking2
# id=centralintelligence
# id=allegiant
# id=mebeforeyou
# id=huntsman
# id=ipman3
# id=godsofegypt
# id=iceage5
# id=detectivechinatown
# id=ridealong2
# id=howtobesingle
# id=5thwave
# id=badrobot2016
# id=universalcomedy2016
# id=thelittleprince
# id=dirtygrandpa
# id=moneymonster
# id=mybigfatgreekwedding2
# id=michelledarnell
# id=purge3
# id=miraclesfromheaven
# id=13hoursthesecretsoldiersofbenghazi
# id=ghostbusters2016
# id=bfg
# id=boy2016
# id=hailcaesar
# id=theshallows
# id=zoolander2
# id=barbershop3
# id=sultan
# id=finesthours
# id=eddietheeagle
# id=risen
# id=thewitch
# id=mikeanddave
# id=forest
# id=niceguys
# id=mothersday
# id=grimsby
# id=untitledtinafeycomedy
# id=solace
# id=fiftyshadesofblack
# id=godsnotdead2
# id=keanu
# id=freestateofjones
# id=elclan
# id=race2016
# id=thechoice
# id=eyeinthesky
# id=thewildlife2016
# id=absolutelyfabulousthemovie
# id=regression
# id=neerja
# id=normofthenorth
# id=prideprejudicezombies
# id=kapoorsons
# id=criminal2015
# id=hello,mynameisdoris
# id=hardcorehenry
# id=othersideofthedoor
# id=lovefriendship
# id=triplenine
# id=bhtilt2016
# id=theperfectmatch
# id=ratchetandclank
# id=singstreet
# id=thelobster
# id=theinfiltrator
# id=christthelord
# id=midnightspecial
# id=menchicken
# id=themeddler
# id=ahologramfortheking
# id=abeautifulplanet
# id=wheretoinvadenext
# id=themanwhoknewinfinity
# id=swissarmyman
# id=smoker
# id=greenroom
# id=compadres
# id=maggiesplan
# id=ourkindoftraitor
# id=milesahead
# id=theprogram2015
# id=abiggersplash
# id=demolition
# id=busconovioparamimujer
# id=aperfectday
# id=fan16
# id=isawthelight
# id=weiner
# id=janegotagun
# id=huntforwilderpeople
# id=embraceoftheserpent
# id=housefull3
# id=theneondemon
# id=genius
# id=lazerteam
# id=mama2015
# id=wazir
# id=dough
# id=elvisnixon
# id=gentleman
# id=kiandka
# id=chongqinghotpot
# id=wailing
# id=cityofgold
# id=knightofcups
# id=fitoor
# id=thefirstmondayinmay
# id=marguerite
# id=theboyandthebeast
# id=onlyyesterday2016
# id=baaghi
# id=captainfantastic
# id=theinnocents
# id=tickled
# id=cafesociety
# id=coldwar2
# id=te3n
# id=highrise
# id=francofonia
# id=aprilandtheextraordinaryworld
# id=mygoldendays
# id=thefamilyfang
# id=dheepan
# id=theinvitation
# id=kaptaan
# id=viva
# id=thewave
# id=louderthanbombs
# id=borntobebluecanada
# id=rams
# id=sunsetsong
# id=tumbledown
# id=spiritshomecoming
# id=awar
# id=hockney
# id=three
# id=measureofaman
# id=aferim
# id=taleoftales
# id=ourlasttango
# id=newyorknewyork16
# id=noonelifeeasy
# id=mountainsmaydepart
# id=fireworkswednesday
# id=lescowboys
# id=sweetbean
# id=saalakhadoos
# id=sweet20
# id=ourlittlesister
# id=thedarkhorse
# id=phantomdetective
# id=ran2016
# id=timerenegades
# id=dongju
# id=lattesa
# id=clown2016
# id=diaryofachambermaid
# id=highstrung2016
# id=theclub
# id=thelastmanonthemoon
# id=cemeteryofsplendor
# id=likeforlikes
# id=intheshadowofwomen
# id=pele
# id=thetreasure16
# id=dontcrossthatriver
# id=amelodytoremember
# id=phantomofthetheatre
# id=mastizaade
# id=troublemakers
# id=songsmybrotherstaughtme
# id=mrright16
# id=eisensteininguanajuato
# id=rioiloveyou
# id=fromafar
# id=valleyoflove
# id=blackway
# id=anesthesia
# id=papa2016
# id=standingtall
# id=chevalier
# id=newyearseveofoldlee
# id=monsterthousandheads
# id=lolo
# id=sanamterikasam
# id=termlife
# id=lastcabtodarwin
# id=rightnowwrongthen
# id=colonia
# id=rememberyou
# id=argentina
# id=adderalldiaries
# id=theonesbelow
# id=serialkiller1
# id=equals
# id=thelastking
# id=mojave
# id=theywillhavetokillusfirst
# id=theotherside
# id=searchparty
# id=inharmony
# id=nexttimeillaimfortheheart
# '\nww2016 = pd.read_csv("worldwide_releases_2016_v2.csv")\n\nfor index, element in ww2016.iterrows():\n    title = element.Movie_link.split(\'?\')[1].split(\'.\')[0]\n    print(title)\n    time.sleep(random.randint(3,7))\n    pullData(title)\n    time.sleep(random.randint(3,7))\n'

# %%
pullData(linkList[2])
# Out:
# C:\Python34\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-2546a57255e3> in <module>()
# ----> 1 pullData(linkList[2])
#
# <ipython-input-6-705df4c3b32a> in pullData(subUrl)
#      36
#      37     topBox = box[4]
# ---> 38     countryData = box[7]
#      39
#      40     countryDataList = []
#
# IndexError: list index out of range
